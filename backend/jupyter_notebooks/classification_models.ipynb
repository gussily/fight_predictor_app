# %%
import random

import pandas as pd
import numpy as np
import math

import json
import array as arr
from datetime import datetime, date

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

# %%
with open('data/fighter_elos.json') as json_file:
    elo_dict = json.load(json_file)
    
with open('data/fighter_elos_ignore_loser_10_29.json') as json_file:
    elo_dict_winner = json.load(json_file)
    
# dateparse = lambda x: datetime.strptime(x, '%Y-%m-%d')
df_stat_data = pd.read_csv('data/df_stat_data_10_25.csv')
df_fight_data = pd.read_csv('data/df_fight_data_10_25.csv')

with open('data/fighter_hist.json') as json_file:
    fighter_dict = json.load(json_file)
    
with open('data/fighter_name_to_id.json') as json_file:
    name_dict = json.load(json_file)

# %%
# %run ./elo_generation.ipynb

# %%
# elo_win_loss = Elo(fighter_dict, df_fight_data, df_stat_data, name_dict, ['clinch'])

# %%
# elo_ignore_loser = Elo(fighter_dict = fighter_dict,
#                        df_fight_data = df_fight_data,
#                        df_stat_data = df_stat_data,
#                        name_dict = name_dict,
#                        stat_names = list(df_stat_data.Stat.unique()),
#                        ignore_winner=False)

# %%
# elo_ignore_loser.to_json('data/fighter_elos_ignore_loser_10_29.json')

# %%
def gen_train_test(elo_dict, fighter_dict, df_fight_data, stat_names, random_state=0):
    df_elo = gen_df_elo(df_fight_data, elo_dict, stat_names)
    df_elo = filter_columns(df_elo)
    df_elo = randomize_result(df_elo)
    df_x, df_y = gen_x_y(df_elo)
    df_x = adjust_range(df_x)
    return train_test_split(df_x, df_y, test_size=0.25, random_state=random_state)
    
def gen_df_elo(df_fight_data, elodict, stat_names, divby=400, check_win=False):
    returned = df_fight_data.copy()
    for stat_name in stat_names:
        def to_apply(row):
            f0_elo = elodict[str(row['fighter_0'])][row['date']][stat_name]
            f1_elo = elodict[str(row['fighter_1'])][row['date']][stat_name]
            
            return Elo.prob(f0_elo, f1_elo, divby)[1]
            
        returned['elo_'+stat_name] = returned.apply(to_apply, axis=1)
    return returned

def filter_columns(df_elo):
    return df_elo[list(filter(lambda col: (col == 'winner') or ('elo' in col),
                             df_elo.columns))]

def randomize_result(df_elo):
    df_elo = df_elo.copy()
    for i in df_elo.index:
        if random.randint(0, 1) == 0:
            df_elo.loc[i] = [1-x for x in df_elo.loc[i]]
    return df_elo

def gen_x_y(df_elo):
    x = df_elo[list(filter(lambda col: col != 'winner', df_elo.columns))]
    y = df_elo[['winner']]
    return x, y

def adjust_range(df_x):
    df_x = df_x.copy()
    for col in df_x.columns:
        df_x[col] = df_x[col] - .5
    return df_x

# %%
name_dict['Khabib Nurmagomedov']
# Out:
# 421

# %%
elo_ignore_loser.elodict[421]
# Out:
# {'curr': {'win_loss': 305.9153506946926,
#   'kd': 149.9920560333268,
#   'sig str': 288.21753204412295,
#   'total str': 285.71619767411585,
#   'td': 259.74500219290866,
#   'sub att': 192.2316035656752,
#   'pass': 261.0686925642812,
#   'rev': 120.42425096822464,
#   'head': 285.58617871515435,
#   'body': 154.53395106106157,
#   'leg': 198.26175057987086,
#   'distance': 208.64438067706027,
#   'clinch': 224.63400535281517,
#   'ground': 279.2530036901879},
#  Timestamp('2012-01-20 00:00:00'): {'kd': 120.42425096822464,
#   'sig str': 120.42425096822464,
#   'total str': 120.42425096822464,
#   'td': 120.42425096822464,
#   'sub att': 120.42425096822464,
#   'pass': 120.42425096822464,
#   'rev': 120.42425096822464,
#   'head': 120.42425096822464,
#   'body': 120.42425096822464,
#   'leg': 120.42425096822464,
#   'distance': 120.42425096822464,
#   'clinch': 120.42425096822464,
#   'ground': 120.42425096822464,
#   'win_loss': 120.42425096822464},
#  Timestamp('2012-07-07 00:00:00'): {'kd': 140.11142258530714,
#   'sig str': 140.3525267159697,
#   'total str': 140.24582739292464,
#   'td': 141.5742735239154,
#   'sub att': 140.41332630412464,
#   'pass': 140.22423544649445,
#   'rev': 120.42425096822464,
#   'head': 140.29890483276478,
#   'body': 140.1113908431099,
#   'leg': 120.42425096822464,
#   'distance': 140.28246709123414,
#   'clinch': 140.2178126691918,
#   'ground': 140.23104830375698,
#   'win_loss': 140.42425096822464},
#  Timestamp('2013-01-19 00:00:00'): {'kd': 140.11142258530714,
#   'sig str': 140.3525267159697,
#   'total str': 140.24582739292464,
#   'td': 141.5742735239154,
#   'sub att': 140.41332630412464,
#   'pass': 140.22423544649445,
#   'rev': 120.42425096822464,
#   'head': 140.29890483276478,
#   'body': 140.1113908431099,
#   'leg': 132.16510333803586,
#   'distance': 140.28246709123414,
#   'clinch': 154.3781819959149,
#   'ground': 140.23104830375698,
#   'win_loss': 158.6005887075543},
#  Timestamp('2013-05-25 00:00:00'): {'kd': 149.9920560333268,
#   'sig str': 155.93316981006265,
#   'total str': 155.0897165709618,
#   'td': 141.5742735239154,
#   'sub att': 140.41332630412464,
#   'pass': 155.5916937986792,
#   'rev': 120.42425096822464,
#   'head': 156.59070032210133,
#   'body': 140.1113908431099,
#   'leg': 132.16510333803586,
#   'distance': 153.41993282583402,
#   'clinch': 154.3781819959149,
#   'ground': 154.5613986196949,
#   'win_loss': 173.1890274467844},
#  Timestamp('2013-09-21 00:00:00'): {'kd': 149.9920560333268,
#   'sig str': 167.97272596997425,
#   'total str': 167.11971086866794,
#   'td': 153.293301791133,
#   'sub att': 153.09944227508342,
#   'pass': 166.65348339110898,
#   'rev': 120.42425096822464,
#   'head': 168.59815446122752,
#   'body': 140.1113908431099,
#   'leg': 145.38662772141356,
#   'distance': 164.58204854552105,
#   'clinch': 154.3781819959149,
#   'ground': 166.66708392037117,
#   'win_loss': 184.36184275732992},
#  Timestamp('2014-04-19 00:00:00'): {'kd': 149.9920560333268,
#   'sig str': 178.99244969451124,
#   'total str': 177.28155800163555,
#   'td': 165.0003042076935,
#   'sub att': 153.09944227508342,
#   'pass': 176.83568803485724,
#   'rev': 120.42425096822464,
#   'head': 178.6956240627534,
#   'body': 140.1113908431099,
#   'leg': 145.38662772141356,
#   'distance': 175.7582846944485,
#   'clinch': 154.3781819959149,
#   'ground': 176.84869432598208,
#   'win_loss': 193.78983728474245},
#  Timestamp('2016-04-16 00:00:00'): {'kd': 149.9920560333268,
#   'sig str': 194.15927632532578,
#   'total str': 194.23236415529124,
#   'td': 181.62402809343112,
#   'sub att': 153.09944227508342,
#   'pass': 194.18521944690136,
#   'rev': 120.42425096822464,
#   'head': 196.7162133025493,
#   'body': 140.1113908431099,
#   'leg': 162.11614258150243,
#   'distance': 175.7582846944485,
#   'clinch': 170.64142839041432,
#   'ground': 193.9192955299207,
#   'win_loss': 211.35807775597053},
#  Timestamp('2016-11-12 00:00:00'): {'kd': 149.9920560333268,
#   'sig str': 215.14851102511938,
#   'total str': 215.21740183072333,
#   'td': 203.3314910215387,
#   'sub att': 153.09944227508342,
#   'pass': 215.1729643886336,
#   'rev': 120.42425096822464,
#   'head': 217.55856815672627,
#   'body': 140.1113908431099,
#   'leg': 184.93190771934596,
#   'distance': 175.7582846944485,
#   'clinch': 192.97459570275095,
#   'ground': 214.92231036535384,
#   'win_loss': 231.35807775597053},
#  Timestamp('2017-12-30 00:00:00'): {'kd': 149.9920560333268,
#   'sig str': 228.6986705627376,
#   'total str': 228.8022019657855,
#   'td': 214.15978544707724,
#   'sub att': 153.09944227508342,
#   'pass': 222.12982183946002,
#   'rev': 120.42425096822464,
#   'head': 229.3893230775249,
#   'body': 140.1113908431099,
#   'leg': 184.93190771934596,
#   'distance': 175.7582846944485,
#   'clinch': 205.7616350019993,
#   'ground': 226.67434254883455,
#   'win_loss': 243.48688819855894},
#  Timestamp('2018-04-07 00:00:00'): {'kd': 149.9920560333268,
#   'sig str': 242.44812473102584,
#   'total str': 241.8831438892697,
#   'td': 224.4145946128083,
#   'sub att': 153.09944227508342,
#   'pass': 229.84524389678728,
#   'rev': 120.42425096822464,
#   'head': 237.5111445213471,
#   'body': 140.1113908431099,
#   'leg': 184.93190771934596,
#   'distance': 194.14957118142658,
#   'clinch': 205.7616350019993,
#   'ground': 237.38086441172317,
#   'win_loss': 259.54669170103915},
#  Timestamp('2018-10-06 00:00:00'): {'kd': 149.9920560333268,
#   'sig str': 255.81002387715873,
#   'total str': 253.72631565057506,
#   'td': 234.35571224611667,
#   'sub att': 163.88511584053322,
#   'pass': 237.5180596368561,
#   'rev': 120.42425096822464,
#   'head': 251.80950931915385,
#   'body': 140.1113908431099,
#   'leg': 198.26175057987086,
#   'distance': 208.64438067706027,
#   'clinch': 205.7616350019993,
#   'ground': 251.1237195491415,
#   'win_loss': 272.4366916806207},
#  Timestamp('2019-09-07 00:00:00'): {'kd': 149.9920560333268,
#   'sig str': 271.2268571883861,
#   'total str': 269.3270799125318,
#   'td': 245.33976248645368,
#   'sub att': 177.11007335110435,
#   'pass': 249.3703751383387,
#   'rev': 120.42425096822464,
#   'head': 268.23008391279893,
#   'body': 140.1113908431099,
#   'leg': 198.26175057987086,
#   'distance': 208.64438067706027,
#   'clinch': 205.7616350019993,
#   'ground': 266.03620813830526,
#   'win_loss': 288.9015300972143}}

# %%
[a['sig str'] for a in elo_dict_winner['421'].values()]
# Out:
# [288.21753204412295,
#  120.42425096822464,
#  140.3525267159697,
#  140.3525267159697,
#  155.93316981006265,
#  167.97272596997425,
#  178.99244969451124,
#  194.15927632532578,
#  215.14851102511938,
#  228.6986705627376,
#  242.44812473102584,
#  255.81002387715873,
#  271.2268571883861]

# %%
x_train, x_test, y_train, y_test = \
    gen_train_test(elo_dict_winner, fighter_dict, df_fight_data,
                   ['clinch'],
                   random_state=3)

# %%
def get_accuracy(x_train, x_test, y_train, y_test,
                 model=LogisticRegression(solver='lbfgs')):
    mod = model.fit(x_train, y_train)
    return mod, mod.score(x_test, y_test)

model, score = get_accuracy(x_train, x_test, y_train, y_test)
score
# Out:
# C:\Users\augus\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.5336356764928194

# %%
get_accuracy(x_train, x_train, y_train, y_train)[1]
# Out:
# C:\Users\augus\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.54421768707483

# %%
[print(a) for a in ['sig str', 'td', 'head', 'distance', 'clinch',
                    'ground']]
# Out:
# sig str
# td
# head
# distance
# clinch
# ground
# win_loss
# [None, None, None, None, None, None, None]

# %%
relevant_cols
# Out:
# ['sig str', 'total str', 'td', 'pass', 'head', 'distance', 'clinch', 'ground']

# %%
x_train[['elo_'+c for c in relevant_cols] + ['elo_win_loss']].corr()
# Out:
#                elo_sig str  elo_total str    elo_td  elo_pass  elo_head  \
# elo_sig str       1.000000       0.908121  0.575702  0.594071  0.901790
# elo_total str     0.908121       1.000000  0.617166  0.643003  0.855016
# elo_td            0.575702       0.617166  1.000000  0.859386  0.585807
# elo_pass          0.594071       0.643003  0.859386  1.000000  0.595649
# elo_head          0.901790       0.855016  0.585807  0.595649  1.000000
# elo_distance      0.823276       0.737328  0.377623  0.389858  0.745472
# elo_clinch        0.757454       0.734320  0.533615  0.529827  0.711989
# elo_ground        0.792742       0.783471  0.705827  0.721796  0.810832
# elo_win_loss      0.859649       0.841151  0.678286  0.695329  0.840643
#
#                elo_distance  elo_clinch  elo_ground  elo_win_loss
# elo_sig str        0.823276    0.757454    0.792742      0.859649
# elo_total str      0.737328    0.734320    0.783471      0.841151
# elo_td             0.377623    0.533615    0.705827      0.678286
# elo_pass           0.389858    0.529827    0.721796      0.695329
# elo_head           0.745472    0.711989    0.810832      0.840643
# elo_distance       1.000000    0.664339    0.561978      0.703317
# elo_clinch         0.664339    1.000000    0.662712      0.692935
# elo_ground         0.561978    0.662712    1.000000      0.789731
# elo_win_loss       0.703317    0.692935    0.789731      1.000000

# %%
list(model.coef_[0])
# Out:
# [1.1416526090048817]

# %%
_, stest = get_accuracy(x_train, x_train, y_train, y_train)
stest
# Out:
# C:\Users\augus\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.580750818846057

# %%
predicted_train = list(model.predict(x_train))
correct = 0
for i in range(len(predicted_train)):
    if predicted_train[i] == list(y_train.winner)[i]:
        correct += 1
        
print(correct/len(predicted_train))
# Out:
# 0.5813822284908322

# %%
model_nb, score_nb = get_accuracy(x_train, x_test, y_train, y_test,
                                  model=GaussianNB())
score_nb
# Out:
# C:\Users\augus\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.5500858614768174

# %%
def get_relevant_cols(x_train, model):
    cols = list(x_train.columns)
    coefs = list(model.coef_[0])
    cols_or_none = [cols[i][4:] if coefs[i] > 0 else None for i in range(len(coefs))]
    return list(filter(lambda x: not x is None, cols_or_none))

relevant_cols = get_relevant_cols(x_train, model)
relevant_cols
# Out:
# ['sig str', 'total str', 'td', 'pass', 'head', 'distance', 'clinch', 'ground']

# %%
model_v2, score_2 = get_accuracy(*gen_train_test(elo_dict_winner, fighter_dict, df_fight_data,
#                                                  list(df_stat_data.Stat.unique()) + ['win_loss'],
                                                 ['win_loss', 'head', 'td', 'sig str'],
                                                 random_state=5))

score_2
# Out:
# C:\Users\augus\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.5603892386949055

# %%
[a if a==0 else None for a in [0,1,2]]
# Out:
# [0, None, None]

# %%
x_train.columns
# Out:
# Index(['elo_kd', 'elo_sig str', 'elo_total str', 'elo_td', 'elo_sub att',
#        'elo_pass', 'elo_rev', 'elo_head', 'elo_body', 'elo_leg',
#        'elo_distance', 'elo_clinch', 'elo_ground', 'elo_win_loss'],
#       dtype='object')

# %%
{relevant_cols[i]: list(model_v2.coef_[0])[i] for i in range(len(relevant_cols))}
# Out:
# {'sig str': 2.092784028353675,
#  'total str': 0.4152194696347669,
#  'td': 0.19291105105542655,
#  'pass': -0.44891031504484497,
#  'head': 1.6597123287713962,
#  'distance': -0.32163704238556823,
#  'clinch': -0.8852864261542588,
#  'ground': -0.27346492352883095,
#  'win_loss': 0.18592028403341884}

# %%
list(model_v2.coef_[0])
# Out:
# [-0.4592955621157757,
#  1.6843825603098663,
#  0.10392205456768783,
#  1.7306195963331343]

# %%
model.coef_
# Out:
# array([[-0.77882573,  1.87713765,  0.70653025,  0.85726798, -1.02963589,
#          0.39239353, -2.85534916,  1.57252398, -0.34622638, -0.90063324,
#          1.02886282,  0.48301515,  0.59788978, -0.11711049]])

# %%
df_fight_data
# Out:
#                                              fight_name  fighter_0  fighter_1  \
# 0            Tulio Palhares v Adriano Santos 1998-10-16       1899       1900
# 1        Ebenezer Fontes Braga v Jeremy Horn 1998-10-16       1898       1601
# 2           Tsuyoshi Kohsaka v Pete Williams 1998-10-16       1813       1819
# 3               Pat Miletich v Mikey Burnett 1998-10-16       1818       1893
# 4                 Pedro Rizzo v David Abbott 1998-10-16       1785       1784
# 5            Vitor Belfort v Wanderlei Silva 1998-10-16        734       1306
# 6                Frank Shamrock v John Lober 1998-10-16       1870       1897
# 7              Laverne Clark v Frank Caracci 1999-01-08       1844       1896
# 8                Evan Tanner v Darrel Gholar 1999-01-08       1634       1895
# 9          Mikey Burnett v Townsend Saunders 1999-01-08       1893       1894
# 10              Tito Ortiz v Jerry Bohlander 1999-01-08       1373       1892
# 11                Pedro Rizzo v Mark Coleman 1999-01-08       1785       1539
# 12               Pat Miletich v Jorge Patino 1999-01-08       1818       1891
# 13             Bas Rutten v Tsuyoshi Kohsaka 1999-01-08       1882       1813
